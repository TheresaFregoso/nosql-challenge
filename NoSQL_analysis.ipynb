# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient, GEOSPHERE
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the establishments database to a variable name
print(mongo.list_database_names())
db = mongo['uk_food']
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'establishments', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
print("Number of documents in result (hygiene = 20):", establishments.count_documents(query))
# Display the first document in the results using pprint
establishments_docs = db.establishments.find_one(query)

# Print one document
pprint(establishments_docs)
# Out:
# Number of documents in result (hygiene = 20): 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a869e04c4875b3d700c400'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
# ...

# %%
# Convert the result to a Pandas DataFrame
# Fetch all documents matching the query
establishments_docs = list(establishments.find(query))

# Convert the result to a Pandas DataFrame
bad_hygiene = pd.DataFrame(establishments_docs)

# Display the number of rows in the DataFrame
print("Number of rows in result: ", len(bad_hygiene))


# Display the first document in the results 
bad_hygiene.head(10)
# Out:
# Number of rows in result:  33
#                         _id   FHRSID  ChangesByServerID  \
# 0  66a869e14c4875b3d700de19   621707                  0
# 1  66a869e14c4875b3d700e141  1130836                  0
# 2  66a869e14c4875b3d700ec8f   293783                  0
# 3  66a869e14c4875b3d700fa92   294474                  0
# 4  66a869e14c4875b3d700fa98  1315095                  0
# 5  66a869e24c4875b3d7010198   294900                  0
# 6  66a869e24c4875b3d70122a6   293756                  0
# 7  66a869e24c4875b3d701266c   878523                  0
# 8  66a869e24c4875b3d7012686   295107                  0
# 9  66a869e24c4875b3d7012689   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {
    'LocalAuthorityName': {'$regex':'London'},
    'RatingValue': {'$gte': 4}
    }

# Use count_documents to display the number of documents in the result
print("Number of documents in result (Ratings Value > or = to 4):", establishments.count_documents(query))
# Display the first document in the results using pprint
establishments_docs = db.establishments.find_one(query)

# Print one document
pprint(establishments_docs)
# Out:
# Number of documents in result (Ratings Value > or = to 4): 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a869e14c4875b3d700de19'),
#  'geocode': {'latitude': Decimal128('51.369321'),
# ...

# %%
# Convert the result to a Pandas DataFrame
establishments_docs = list(establishments.find(query))
good_rating = pd.DataFrame(establishments_docs)

# Display the number of rows in the DataFrame
print("Number of rows in result: ", len(good_rating))
# Display the first 10 rows of the DataFrame
good_rating.head(10)
# Out:
# Number of rows in result:  33
#                         _id   FHRSID  ChangesByServerID  \
# 0  66a869e14c4875b3d700de19   621707                  0
# 1  66a869e14c4875b3d700e141  1130836                  0
# 2  66a869e14c4875b3d700ec8f   293783                  0
# 3  66a869e14c4875b3d700fa92   294474                  0
# 4  66a869e14c4875b3d700fa98  1315095                  0
# 5  66a869e24c4875b3d7010198   294900                  0
# 6  66a869e24c4875b3d70122a6   293756                  0
# 7  66a869e24c4875b3d701266c   878523                  0
# 8  66a869e24c4875b3d7012686   295107                  0
# 9  66a869e24c4875b3d7012689   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

# Ensure the collection has a geospatial index on the geocode field
db.establishments.create_index([("geocode", GEOSPHERE)])

# Define the location of "Penang Flavours"
penang_flavours_location = [0.08384000, 51.49014200] 

# Define the geospatial query and sorting criteria
near_query = {
    'RatingValue': 5,
    'geocode': {
        '$near': {
            '$geometry': {
                'type': "Point",
                'coordinates': penang_flavours_location
            },
            '$maxDistance': 1000  # 1000 meters (1km) radius
        }
    }
}

# Fetch the top 5 establishments matching the criteria, sorted by Hygiene score
establishments_docs = list(establishments.find(near_query).sort('scores.Hygiene', 1).limit(5))

# Print the results
pprint(establishments_docs)
# Out:
# [{'AddressLine1': 'Plumstead Railway Station Walmer Terrace',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Wilson & Bay Coffee Club',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4647.351960555438,
#   'FHRSID': 1489067,
#   'LocalAuthorityBusinessID': '15088',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 7EA',
#   'RatingDate': '2021-12-09T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('66a869e24c4875b3d7011edd'),
#   'geocode': {'latitude': Decimal128('51.4897501'),
#               'longitude': Decimal128('0.0839053')},
# ...

# %%
# Convert result to Pandas DataFrame
top_establishments_all = list(establishments.find(near_query).sort('scores.Hygiene', 1))
top_establishments_all_df = pd.DataFrame(top_establishments_all)
top_establishments_all_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  66a869e24c4875b3d7011ee4  1319113                  0
# 1  66a869e24c4875b3d7011ed5   694635                  0
# 2  66a869e24c4875b3d7011edd  1489067                  0
# 3  66a869e24c4875b3d7011f15  1392055                  0
# 4  66a869e24c4875b3d7011ecc   695316                  0
# 5  66a869e24c4875b3d7011e92   695243                  0
# 6  66a869e24c4875b3d7011e90   841434                  0
# 7  66a869e24c4875b3d7011e6d   695597                  0
# 8  66a869e24c4875b3d7011e60  1156705                  0
# 9  66a869e24c4875b3d7011e64  1274352                  0
#
#   LocalAuthorityBusinessID                      BusinessName  \
# 0                    14007                  Suya Academy Ltd
# 1             PI/000117510            Jhas Catering Services
# 2                    15088          Wilson & Bay Coffee Club
# 3                    14546          Greenwich Islamic Centre
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
hygiene_query = {'$match': {'scores.Hygiene': 0}}

# 2. Groups the matches by Local Authority
group_query = {
    '$group': {
        '_id': '$LocalAuthorityName',  # Group by Local Authority Name
        'count': {'$sum': 1}  # Count each document
    }
}

# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': {'count': -1}}

#assemble the pipeline
pipeline = [hygiene_query, group_query, sort_values]

# Run the pipeline through the aggregate method, cast the results as a list, and save the results to a variable
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print("Number of rows in result: ", len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of rows in result:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
aggregated_df = pd.json_normalize(results)
# Display the number of rows in the DataFrame
print(f"Number of rows in DataFrame: {len(aggregated_df)}")
# Display the first 10 rows of the DataFrame
aggregated_df.head(10)
# Out:
# Number of rows in DataFrame: 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
